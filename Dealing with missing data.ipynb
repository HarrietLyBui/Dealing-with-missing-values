# %%
import warnings
import pandas as pd
import numpy as np
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.models import HoverTool, ColumnDataSource, Title
import math

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fa102ea3-e340-4c66-a2fe-9a580584aaae">Loading BokehJS ...</span>
#     </div>

# %%
#ignore warning for now
warnings.filterwarnings('ignore')

data = pd.read_csv('Wholesale customers data-missing.csv')
original_data = pd.read_csv('Wholesale customers data.csv')

# %%
data.head()
# Out:
#    Channel  Region  Fresh    Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669  9656.0   7561.0     214            2674.0
# 1        2       3   7057  9810.0   9568.0    1762            3293.0
# 2        2       3   6353  8808.0   7684.0    2405            3516.0
# 3        1       3  13265  1196.0   4221.0    6404             507.0
# 4        2       3  22615  5410.0   7198.0    3915            1777.0
#
#    Delicassen
# 0      1338.0
# 1      1776.0
# 2      7844.0
# 3      1788.0
# 4      5185.0

# %%
data.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                1
# Grocery             2
# Frozen              0
# Detergents_Paper    2
# Delicassen          1
# dtype: int64

# %%
data[data.Milk.isnull()]
# Out:
#      Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 180        1       3  12356   NaN   8887.0     402            1382.0
#
#      Delicassen
# 180      2794.0

# %%
data[data.Detergents_Paper.isnull()]
# Out:
#      Channel  Region  Fresh    Milk  Grocery  Frozen  Detergents_Paper  \
# 225        1       1  12680  3243.0   4157.0     660               NaN
# 370        2       3  39679  3944.0   4955.0    1364               NaN
#
#      Delicassen
# 225       786.0
# 370      2235.0

# %%
data[data.Grocery.isnull()]
# Out:
#      Channel  Region  Fresh    Milk  Grocery  Frozen  Detergents_Paper  \
# 75         1       3  20398  1137.0      NaN    4407               3.0
# 172        1       3    955  5479.0      NaN     333            2840.0
#
#      Delicassen
# 75        975.0
# 172       707.0

# %%
data.shape
# Out:
# (440, 8)

# %%
#Handling missing value 1: Drop the data

# drop all rows with missing data
data_drop = data.dropna(how='any')

# %%
data_drop.shape
# Out:
# (434, 8)

# %%
#Drop a row if any of data in Milk or Delicassen are missing
data.dropna(subset=['Milk','Delicassen'], how='any').shape
# Out:
# (438, 8)

# %%
#Handle missing value 2: use a global constant
#Replace missing data with -1, inplace = True(make the change 
#in place in the dataframe)
data_with_const = data
data_with_const.fillna(value=-1, inplace=True)

# %%
data_with_const.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
#Handle missing value 3: use the attribute mean
data_with_mean = data
data_with_mean.replace(-1, np.nan, inplace=True)
data_with_mean.iloc[225]
data_with_mean.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                1
# Grocery             2
# Frozen              0
# Detergents_Paper    2
# Delicassen          1
# dtype: int64

# %%
#Find NaN value and replace it with the mean of the column

for label in data_with_mean.columns:
    if data_with_mean.loc[:][label].isnull().sum() > 0:
        mean_value = math.floor(data_with_mean.loc[:][label].mean())
        print(mean_value)
        data_with_mean.loc[:][label].fillna(value = mean_value, inplace=True)

data_with_mean.iloc[225][:]
# Out:
# 5795.0
# 7972.0
# 2891.0
# 1525.0
# Channel                 1.0
# Region                  1.0
# Fresh               12680.0
# Milk                 3243.0
# Grocery              4157.0
# Frozen                660.0
# Detergents_Paper     2891.0
# Delicassen            786.0
# Name: 225, dtype: float64

# %%
original_data.iloc[225][:]
# Out:
# Channel                 1
# Region                  1
# Fresh               12680
# Milk                 3243
# Grocery              4157
# Frozen                660
# Detergents_Paper      761
# Delicassen            786
# Name: 225, dtype: int64

# %%
#Method take in a data frame with its description of the dataset of type String
#Draw a scatter plot identifying relationship between milk and grocery of that datata
#Add interactions such as box zoom, box selection, pan, wheel zoom, reset
#Add hover tool to show specific data values

def visualize_data (data_frame, dataset_type):
    region_value = data_frame.loc[:, 'Region'] == 1
    

    full_title = 'ANNUAL SALE IN REGION 1 FOR MILK AND GROCERY ($)'
    
    p = figure(x_axis_label='groceries annual sale', y_axis_label= 'milk annual sale', 
               title = full_title, tools=['box_select,pan,wheel_zoom,box_zoom,reset'], 
               toolbar_location="right", toolbar_sticky=False)
    
    #Add subtitle at the bottom of the graph
    p.add_layout(Title(text=dataset_type, align="center"), "below")
    p.title.align="center"

    # Create a scatter plot 
    scatter_plot = p.circle( x=data_frame[region_value]['Grocery'], y=data_frame[region_value]['Milk'], 
                             size=10, color='green',  selection_color='red', nonselection_alpha=0.1, 
                             hover_fill_color='green', hover_alpha=0.5, hover_line_color='white')

    #Create a HoverTool to show value of annual sales in milk and grocery
    hover = HoverTool(renderers=[scatter_plot], tooltips=[('Milk ($)', '@y'), ('Groceries ($)', '@x') ])


    #Size of small ruler lines on axises 
    p.axis.minor_tick_in = 3
    p.axis.minor_tick_out = 6

    #Add the hover tool to the figure p
    p.add_tools(hover)
    show(p)
    
    return

# %%
#Visualize the complete dataset
visualize_data(original_data, 'complete dataset')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b8047674-66b6-4f4e-877e-ac1827ade17e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b8047674-66b6-4f4e-877e-ac1827ade17e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b8047674-66b6-4f4e-877e-ac1827ade17e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b8047674-66b6-4f4e-877e-ac1827ade17e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dbd0e7e7-be2a-49e0-94e5-eb00f350b4ba":{"roots":{"references":[{"attributes":{"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"}},"id":"72f5bb13-fe71-45bb-9846-921a05311bab","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[4897,10391,6824,2112,23127,24708,9490,2216,5226,23596,950,6089,5838,16767,1393,39694,2062,6861,11364,15538,36486,2046,15205,1390,1382,10646,2856,5265,1499,4157,9212,1563,572,2501,5615,3828,3838,3316,3833,2824,3047,593,585,3779,7041,2475,2914,5119,10817,13916,1777,489,2406,2070,1799,33586,4740,16966,4748,1495,5249,1883,2124,7336,2157,1094,1677,6684,15445,13699,22182,2576,19847,1138,975,1563,6869],"y":[7209,7097,2154,2280,13240,14399,11487,685,891,11711,780,4737,3748,12729,1895,28326,1012,6602,6551,10765,16599,1475,7504,367,899,7503,1115,2527,659,3243,5921,2204,577,2746,5989,10678,1780,4984,2703,6380,820,3838,475,2567,3575,1801,659,3576,7775,6154,2428,346,5279,3795,1993,23133,1860,7961,17972,489,5008,1931,4563,4959,4885,1110,1372,1115,9679,23527,9763,1222,8053,258,1032,5007,8323]}},"id":"a37c055e-5dc2-4d89-be54-d65c0e803138","type":"ColumnDataSource"},{"attributes":{},"id":"1724dc2c-e15a-45e1-b0c1-f6548e6d4ee9","type":"BasicTicker"},{"attributes":{"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"}},"id":"082f1996-8fe3-447b-9f93-53373f22b7c0","type":"ResetTool"},{"attributes":{"callback":null,"overlay":{"id":"13d43e24-6862-4823-aeea-2b4e137df80c","type":"BoxAnnotation"},"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"},"renderers":[{"id":"3a97027b-c25a-4ac0-9d7b-14dec466551c","type":"GlyphRenderer"}]},"id":"3f903887-222a-4b52-9d8a-d1488b972ff5","type":"BoxSelectTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"green"},"line_alpha":{"value":0.5},"line_color":{"value":"white"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"fa3fad80-f803-4bd3-9d75-bb9e0acf64a8","type":"Circle"},{"attributes":{},"id":"e9d1d664-9da4-4db0-bc3e-8fa76f1a40f2","type":"ToolEvents"},{"attributes":{"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"},"ticker":{"id":"1724dc2c-e15a-45e1-b0c1-f6548e6d4ee9","type":"BasicTicker"}},"id":"6efa62c2-bf73-4f25-b86d-db75a4430a81","type":"Grid"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"e70fa9d9-12c9-4b3d-9e21-849ed1b7802e","type":"Circle"},{"attributes":{"axis_label":"milk annual sale","formatter":{"id":"1ceb072f-515a-4814-8b33-119c9617210c","type":"BasicTickFormatter"},"minor_tick_in":3,"minor_tick_out":6,"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"},"ticker":{"id":"cfd299c1-9ac3-4778-83f9-b49f8fc40e0e","type":"BasicTicker"}},"id":"9551341b-3efd-43f7-b442-ffd3f628a891","type":"LinearAxis"},{"attributes":{"overlay":{"id":"6d8942cd-d772-43ee-929a-c71e74bc05dc","type":"BoxAnnotation"},"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"}},"id":"f88ca356-1440-48c7-9767-f94fb07cf449","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"a37c055e-5dc2-4d89-be54-d65c0e803138","type":"ColumnDataSource"},"glyph":{"id":"2d118a06-034b-4dd2-a639-5846ff825cbb","type":"Circle"},"hover_glyph":{"id":"fa3fad80-f803-4bd3-9d75-bb9e0acf64a8","type":"Circle"},"muted_glyph":null,"nonselection_glyph":{"id":"3259aa5b-223f-4519-9e0e-5c1e03d3223b","type":"Circle"},"selection_glyph":{"id":"e70fa9d9-12c9-4b3d-9e21-849ed1b7802e","type":"Circle"}},"id":"3a97027b-c25a-4ac0-9d7b-14dec466551c","type":"GlyphRenderer"},{"attributes":{},"id":"11adea42-f3c8-4ab9-9517-d458fe4185a9","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e6471b2f-8c2d-46c6-a089-335b579f144b","subtype":"Figure","type":"Plot"}},"id":"860e737b-dbdc-40a8-bfaf-5e859d6df060","type":"PanTool"},{"attributes":{"bott ...

# %%
#Visualize the dataset using a global constant to handle missing values

visualize_data(data_with_const, 'use a global constant to handle missing values')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="87a555bb-3f35-4375-945d-0bda8d98bbf7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("87a555bb-3f35-4375-945d-0bda8d98bbf7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("87a555bb-3f35-4375-945d-0bda8d98bbf7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '87a555bb-3f35-4375-945d-0bda8d98bbf7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0f1a328b-1bd2-4dbf-bd2e-0bc9b506ca91":{"roots":{"references":[{"attributes":{"callback":null,"overlay":{"id":"e7dc9ada-871c-4175-9ab8-7993caf026b1","type":"BoxAnnotation"},"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"},"renderers":[{"id":"4d903b71-7179-459e-9ae0-a3fe667fb89f","type":"GlyphRenderer"}]},"id":"44dd8c1b-8d26-4158-9a09-d2e6fca1dce1","type":"BoxSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aa413d8d-bb0b-4826-99f3-363a3ff7dfb8","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"}},"id":"4d09efb8-1b13-43f9-92e5-372a56ea62a0","type":"WheelZoomTool"},{"attributes":{"axis_label":"groceries annual sale","formatter":{"id":"ecb09e04-37c8-4ee6-a923-854a9df87645","type":"BasicTickFormatter"},"minor_tick_in":3,"minor_tick_out":6,"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"},"ticker":{"id":"77b786b5-3856-40df-84f8-02931b1a1850","type":"BasicTicker"}},"id":"b3498674-30e3-43da-976e-f2dc2a298b20","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"},"ticker":{"id":"1c67bc74-d0a0-4c83-b6b8-fe5f6b74ee68","type":"BasicTicker"}},"id":"bb7c0549-f038-458c-8b8c-6b09164e52d3","type":"Grid"},{"attributes":{},"id":"77b786b5-3856-40df-84f8-02931b1a1850","type":"BasicTicker"},{"attributes":{"data_source":{"id":"955510d1-703b-4f11-83c1-ffe7f8c377a7","type":"ColumnDataSource"},"glyph":{"id":"df3dee98-1daf-4846-9cf0-b3974511da7f","type":"Circle"},"hover_glyph":{"id":"3a0472f1-5e22-4e81-81ae-558f5785a1d2","type":"Circle"},"muted_glyph":null,"nonselection_glyph":{"id":"a8ed76bc-f751-489b-b009-db92a96b66c5","type":"Circle"},"selection_glyph":{"id":"6e93741b-2c2b-4c3b-93dc-467d68edfe87","type":"Circle"}},"id":"4d903b71-7179-459e-9ae0-a3fe667fb89f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"}},"id":"32d04a5b-5071-4a89-a564-96b98550e24e","type":"PanTool"},{"attributes":{"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"},"ticker":{"id":"77b786b5-3856-40df-84f8-02931b1a1850","type":"BasicTicker"}},"id":"8da2e823-9918-4330-b468-e65df6df008d","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[77]},"y":{"__ndarray__":"...","dtype":"float64","shape":[77]}}},"id":"955510d1-703b-4f11-83c1-ffe7f8c377a7","type":"ColumnDataSource"},{"attributes":{"axis_label":"milk annual sale","formatter":{"id":"f5c456b8-2135-4b48-8c0e-661884961739","type":"BasicTickFormatter"},"minor_tick_in":3,"minor_tick_out":6,"plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"},"ticker":{"id":"1c67bc74-d0a0-4c83-b6b8-fe5f6b74ee68","type":"BasicTicker"}},"id":"17bb8ef2-f807-49fc-9d0f-cf22f6adf8da","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"green"},"line_alpha":{"value":0.5},"line_color":{"value":"white"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a0472f1-5e22-4e81-81ae-558f5785a1d2","type":"Circle"},{"attributes":{"align":"center","plot":{"id":"5a677f96-5161-4498-85f7-526223ef642e","subtype":"Figure","type":"Plot"},"text":"use a global constant to handle missing values"},"id":"58e10389-d8d2-41a8-afd0-8be3099a8ad1","type":"Title"},{"attributes":{},"id":"1c67bc74-d0a0-4c83-b6b8-fe5f6b74ee68","type":"BasicTicker"},{"attributes":{"callback":null},"id":"b76ab0f2-0937-4021-8038-3a9affdad90a","type":"DataRange1d"},{"attributes":{},"id":"ecb09e04-37c8 ...

# %%
#Visualize the dataset using the attribute mean to handle missing values

visualize_data(data_with_mean, 'use the attribute mean to handle missing values')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6a58ddc3-bdb2-43bd-8865-e08876aacf2b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6a58ddc3-bdb2-43bd-8865-e08876aacf2b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6a58ddc3-bdb2-43bd-8865-e08876aacf2b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6a58ddc3-bdb2-43bd-8865-e08876aacf2b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"44e445bd-79da-4b54-b675-3acb3506389a":{"roots":{"references":[{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4c4487f-f8ee-4f04-9f81-53f94f93c6a4","type":"Circle"},{"attributes":{"callback":null},"id":"3e201c9c-21f3-4a7d-bab3-a60b075f8067","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[77]},"y":{"__ndarray__":"...","dtype":"float64","shape":[77]}}},"id":"60365325-a9c0-4be2-9bb0-6f2e719b5f85","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"736b849e-9e30-4e17-ab8a-6d21e63f3a99","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e3a7265-c600-4062-bc10-184560556fdf","type":"Circle"},{"attributes":{},"id":"d5bf7404-7c88-42c9-8cf2-fae700c47e21","type":"BasicTicker"},{"attributes":{"align":"center","plot":null,"text":"ANNUAL SALE IN REGION 1 FOR MILK AND GROCERY ($)"},"id":"07ef6320-e702-4626-9bd7-ddccf1414bca","type":"Title"},{"attributes":{"axis_label":"groceries annual sale","formatter":{"id":"b17c3c20-17a5-456c-a1cd-d347ee0ca550","type":"BasicTickFormatter"},"minor_tick_in":3,"minor_tick_out":6,"plot":{"id":"c9d3cb49-e11f-4fdb-a48d-8549ab43c211","subtype":"Figure","type":"Plot"},"ticker":{"id":"d5bf7404-7c88-42c9-8cf2-fae700c47e21","type":"BasicTicker"}},"id":"033a9e27-e409-41e1-9aa8-a448ea03e81e","type":"LinearAxis"},{"attributes":{"below":[{"id":"033a9e27-e409-41e1-9aa8-a448ea03e81e","type":"LinearAxis"},{"id":"f04d746f-843e-452f-90d9-a436ffad1f66","type":"Title"}],"left":[{"id":"89f11855-c68f-417b-9d9d-ba66bc23201a","type":"LinearAxis"}],"renderers":[{"id":"033a9e27-e409-41e1-9aa8-a448ea03e81e","type":"LinearAxis"},{"id":"2d9a4e28-e5d5-4af7-83d6-a834bd5c9b6e","type":"Grid"},{"id":"89f11855-c68f-417b-9d9d-ba66bc23201a","type":"LinearAxis"},{"id":"adafd6bf-ae36-4866-8206-1a97443a3d9e","type":"Grid"},{"id":"087300e3-6731-4c9b-b736-c76b810b7952","type":"BoxAnnotation"},{"id":"736b849e-9e30-4e17-ab8a-6d21e63f3a99","type":"BoxAnnotation"},{"id":"f04d746f-843e-452f-90d9-a436ffad1f66","type":"Title"},{"id":"e0c3bc79-c421-4643-9b0f-56b10ded66e3","type":"GlyphRenderer"}],"title":{"id":"07ef6320-e702-4626-9bd7-ddccf1414bca","type":"Title"},"tool_events":{"id":"7d0dad4f-0427-41b4-a2bd-b9040c3721cb","type":"ToolEvents"},"toolbar":{"id":"22d00523-23c6-43b0-8236-d60b0aceab6e","type":"Toolbar"},"toolbar_sticky":false,"x_range":{"id":"ce3b59ee-0168-49f9-84bc-23a08f071761","type":"DataRange1d"},"y_range":{"id":"3e201c9c-21f3-4a7d-bab3-a60b075f8067","type":"DataRange1d"}},"id":"c9d3cb49-e11f-4fdb-a48d-8549ab43c211","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7d0dad4f-0427-41b4-a2bd-b9040c3721cb","type":"ToolEvents"},{"attributes":{"plot":{"id":"c9d3cb49-e11f-4fdb-a48d-8549ab43c211","subtype":"Figure","type":"Plot"}},"id":"e420c2eb-f207-4f25-a440-1dd3897794b4","type":"PanTool"},{"attributes":{"callback":null,"overlay":{"id":"087300e3-6731-4c9b-b736-c76b810b7952","type":"BoxAnnotation"},"plot":{"id":"c9d3cb49-e11f-4fdb-a48d-8549ab43c211","subtype":"Figure","type":"Plot"},"renderers":[{"id":"e0c3bc79-c421-4643-9b0f-56b10ded66e3","type":"GlyphRenderer"}]},"id":"a8665f5d-4285-4959-ae91-86dba8b1b0bb","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"c9d3cb49-e11f-4fdb-a48d-8549ab43c211","subtype":"Figure","type":"Plot"}},"id":"66d83870-b048-4165-abc7-2dae08fcbbdb","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id ...

# %%
#Visualize the dataset dropping rows to handle missing values

visualize_data(data_drop, 'drop rows to handle missing values')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9eacb60d-5bce-4582-b466-0e60430dae71"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9eacb60d-5bce-4582-b466-0e60430dae71");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9eacb60d-5bce-4582-b466-0e60430dae71");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9eacb60d-5bce-4582-b466-0e60430dae71' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5921ead6-2e79-4dfb-bd79-a599c06f8e5f":{"roots":{"references":[{"attributes":{},"id":"69bfc95e-8024-46f1-a9ce-4849f8d916da","type":"ToolEvents"},{"attributes":{"data_source":{"id":"14374909-e0e3-42b0-adf9-ed7d9597ad9b","type":"ColumnDataSource"},"glyph":{"id":"19eae0c2-f43b-4685-8835-253a443996ce","type":"Circle"},"hover_glyph":{"id":"f3794426-89a3-4c1a-acbe-731d444b631e","type":"Circle"},"muted_glyph":null,"nonselection_glyph":{"id":"f0e4c0c4-d6bc-4124-aa54-e16a98b47ece","type":"Circle"},"selection_glyph":{"id":"3f6f007b-36af-4f25-b363-cb5781b8c59f","type":"Circle"}},"id":"3701fb83-2c40-4f2b-8769-a842f36e944f","type":"GlyphRenderer"},{"attributes":{},"id":"24bc3b3e-6fb1-41ff-ae3b-ec57a181498a","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"154e0047-67bf-45e3-9d3e-ec2741fa3349","type":"BoxSelectTool"},{"id":"dfa4172a-bf4f-4896-adaf-0b81b16db847","type":"PanTool"},{"id":"b48e8cd5-58ba-4e1a-a610-eb9377862529","type":"WheelZoomTool"},{"id":"70112707-48fc-4882-ad7d-29631bce2d93","type":"BoxZoomTool"},{"id":"ffd60bda-ae14-43f8-ab0a-1ebf09664aa0","type":"ResetTool"},{"id":"78314275-e366-4b42-81b4-be96597076aa","type":"HoverTool"}]},"id":"475f891e-722b-4d7e-95c0-8b317715d60f","type":"Toolbar"},{"attributes":{"plot":{"id":"202a9af6-b233-4b89-9b48-b1bf56a7d92e","subtype":"Figure","type":"Plot"}},"id":"dfa4172a-bf4f-4896-adaf-0b81b16db847","type":"PanTool"},{"attributes":{"axis_label":"groceries annual sale","formatter":{"id":"322a81d2-32fe-4b9d-9f8b-eb0c3921715a","type":"BasicTickFormatter"},"minor_tick_in":3,"minor_tick_out":6,"plot":{"id":"202a9af6-b233-4b89-9b48-b1bf56a7d92e","subtype":"Figure","type":"Plot"},"ticker":{"id":"89b9eff1-1f52-4d8a-b746-2172936ddf2a","type":"BasicTicker"}},"id":"06fcc487-cd83-4274-9fd6-37f23ed36a0f","type":"LinearAxis"},{"attributes":{"axis_label":"milk annual sale","formatter":{"id":"2be72b6a-2161-488c-a5fa-a216310becda","type":"BasicTickFormatter"},"minor_tick_in":3,"minor_tick_out":6,"plot":{"id":"202a9af6-b233-4b89-9b48-b1bf56a7d92e","subtype":"Figure","type":"Plot"},"ticker":{"id":"24bc3b3e-6fb1-41ff-ae3b-ec57a181498a","type":"BasicTicker"}},"id":"68399747-6ae6-4240-9366-17f0db692815","type":"LinearAxis"},{"attributes":{},"id":"89b9eff1-1f52-4d8a-b746-2172936ddf2a","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f3ac898a-32cc-47e9-8a65-0dd4eb7bc797","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"green"},"line_alpha":{"value":0.5},"line_color":{"value":"white"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"f3794426-89a3-4c1a-acbe-731d444b631e","type":"Circle"},{"attributes":{"callback":null},"id":"6d468f66-95e7-4812-876e-ec3b9c90ed29","type":"DataRange1d"},{"attributes":{"plot":{"id":"202a9af6-b233-4b89-9b48-b1bf56a7d92e","subtype":"Figure","type":"Plot"}},"id":"ffd60bda-ae14-43f8-ab0a-1ebf09664aa0","type":"ResetTool"},{"attributes":{"callback":null,"overlay":{"id":"655523e4-a249-4c65-9d33-908cad39b8ad","type":"BoxAnnotation"},"plot":{"id":"202a9af6-b233-4b89-9b48-b1bf56a7d92e","subtype":"Figure","type":"Plot"},"renderers":[{"id":"3701fb83-2c40-4f2b-8769-a842f36e944f","type":"GlyphRenderer"}]},"id":"154e0047-67bf-45e3-9d3e-ec2741fa3349","type":"BoxSelectTool"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f6f007b-36af-4f25-b363-cb5781b8c59f","type":"Circle"},{"attributes":{"fill_color":{"value":"green"},"line_color":{"value":"green"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"19eae0c2-f43b-468 ...
